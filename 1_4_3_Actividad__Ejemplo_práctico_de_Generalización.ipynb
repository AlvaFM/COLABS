# %% [markdown]
# # Apredizaje y generalización
#
# Keras también nos ayuda a entrenar redes que sean capaces de generalizar de manera muy  simple. En este laboratorio usaremos un conjunto de entrenamiento (train) y otro conjunto diferente de prueba o validación (test). La idea es que entrenaremos con uno y evaluaremos el desempeño de nuestra red en el otro.
#
# También veremos cómo la regularización ayuda a mejorar la generalización.

# %%
# Importamos librerías necesarias

from tensorflow import keras
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt

# %%
# Cargamos datos de entrenamiento y prueba de CIFAR10

(imgs_train,labs_train), (imgs_test,labs_test) = keras.datasets.cifar10.load_data()
print(imgs_train.shape)
print(imgs_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
nombres = ['avión', 'auto', 'pájaro', 'gato', 'venado', 'perro', 'rana', 'caballo', 'barco', 'camión']

# %%
# Mostramos una grilla de ejemplos (al azar) del conjunto de test

h = 6 # alto de la grilla
w = 6 # ancho de la grilla
fig, axs = plt.subplots(h, w, figsize=(1.6*h,1.6*w))
for i in range(h):
  for j in range(w):
    ex = np.random.randint(len(imgs_test))
    axs[i,j].set_title(nombres[labs_test[ex][0]])
    axs[i,j].grid(False)
    axs[i,j].set_xticklabels([])
    axs[i,j].set_yticklabels([])
    axs[i,j].imshow(imgs_test[ex])

# %%
# Tranformamos los datos para el entrenamiento,
# Necesitamos transformar tanto el train como el test

X_train = imgs_train.reshape(50000,32*32*3)
X_test = imgs_test.reshape(10000,32*32*3)
X_train = X_train / 255
X_test = X_test / 255
print('X', X_train.shape, X_test.shape)

Y_train = keras.utils.to_categorical(labs_train, 10)
Y_test = keras.utils.to_categorical(labs_test, 10)
print('Y', Y_train.shape, Y_test.shape)
# Out:
# X (50000, 3072) (10000, 3072)
# Y (50000, 10) (10000, 10)

# %%
# cantidad de ejemplos (train/test), neuronas de entrada y neuronas de salida

M_train = X_train.shape[0]
M_test = X_test.shape[0]

N = X_train.shape[1]
C = Y_train.shape[1]

print(N,C,M_train,M_test)
# Out:
# 3072 10 50000 10000

# %%
# Setamos los seed para números random

np.random.seed(30)
tf.random.set_seed(30)


# Creamos nuestra red feed-forward (tiene 4 capas escondidas!)

h1 = 512
h2 = 256
h3 = 128
h4 = 64

red = keras.Sequential()
red.add(keras.layers.Dense(h1, input_dim=N, activation='relu'))
red.add(keras.layers.Dense(h2, activation='relu'))
red.add(keras.layers.Dense(h3, activation='relu'))
red.add(keras.layers.Dense(h4, activation='relu'))
red.add(keras.layers.Dense(C, activation='softmax'))

red.summary()

red.compile(
    loss='categorical_crossentropy',
    optimizer='sgd',
    metrics=['accuracy']
)
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_37 (Dense)                │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,746,506 (6.66 MB)
#  Trainable params: 1,746,506 (6.66 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
hist = red.fit(X_train, Y_train,
        epochs=150,
        batch_size=512,
        validation_data=(X_test,Y_test)
       )
# Out:
# Epoch 1/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.1985 - loss: 2.2213 - val_accuracy: 0.2529 - val_loss: 2.1297
# Epoch 2/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2741 - loss: 2.0530 - val_accuracy: 0.3030 - val_loss: 1.9929
# Epoch 3/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3154 - loss: 1.9425 - val_accuracy: 0.3308 - val_loss: 1.9114
# Epoch 4/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3353 - loss: 1.8792 - val_accuracy: 0.3506 - val_loss: 1.8482
# Epoch 5/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3506 - loss: 1.8380 - val_accuracy: 0.3660 - val_loss: 1.8090
# Epoch 6/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3617 - loss: 1.8070 - val_accuracy: 0.3758 - val_loss: 1.7794
# Epoch 7/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3714 - loss: 1.7801 - val_accuracy: 0.3766 - val_loss: 1.7608
# Epoch 8/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3807 - loss: 1.7575 - val_accuracy: 0.3839 - val_loss: 1.7412
# Epoch 9/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3866 - loss: 1.7383 - val_accuracy: 0.3901 - val_loss: 1.7276
# Epoch 10/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3940 - loss: 1.7205 - val_accuracy: 0.3968 - val_loss: 1.7086
# Epoch 11/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3987 - loss: 1.7038 - val_accuracy: 0.4008 - val_loss: 1.6976
# Epoch 12/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4036 - loss: 1.6891 - val_accuracy: 0.4054 - val_loss: 1.6855
# Epoch 13/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4097 - loss: 1.6748 - val_accuracy: 0.4101 - val_loss: 1.6704
# Epoch 14/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4153 - loss: 1.6612 - val_accuracy: 0.4150 - val_loss: 1.6596
# Epoch 15/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4202 - loss: 1.6482 - val_accuracy: 0.4188 - val_loss: 1.6496
# Epoch 16/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4248 - loss: 1.6363 - val_accuracy: 0.4241 - val_loss: 1.6312
# Epoch 17/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4297 - loss: 1.6247 - val_accuracy: 0.4273 - val_loss: 1.6243
# Epoch 18/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4347 - loss: 1.6138 - val_accuracy: 0.4324 - val_loss: 1.6107
# Epoch 19/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4383 - loss: 1.6032 - val_accuracy: 0.4345 - val_loss: 1.5982
# Epoch 20/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4422 - loss: 1.5919 - val_accuracy: 0.4389 - val_loss: 1.5896
# Epoch 21/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4453 - loss: 1.5825 - val_accuracy: 0.4435 - val_loss: 1.5791
# Epoch 22/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4487 - loss: 1.5727 - val_accuracy: 0.4460 - val_loss: 1.5698
# Epoch 23/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4523 - loss: 1.5633 - val_accuracy: 0.4466 - val_loss: 1.5647
# Epoch 24/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4549 - loss: 1.5548 - val_accuracy: 0.4483 - val_loss: 1.5610
# Epoch 25/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4577 - loss: 1.5463 - val_accuracy: 0.4506 - val_loss: 1.5543
# Epoch 26/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4608 - loss: 1.5375 - val_accuracy: 0.4521 - val_loss: 1.5467
# Epoch 27/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4632 - loss: 1.5291 - val_accuracy: 0.4532 - val_loss: 1.5427
# Epoch 28/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4661 - loss: 1.5211 - val_accuracy: 0.4531 - val_loss: 1.5383
# Epoch 29/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4689 - loss: 1.5139 - val_accuracy: 0.4580 - val_loss: 1.5318
# Epoch 30/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4722 - loss: 1.5061 - val_accuracy: 0.4605 - val_loss: 1.5271
# Epoch 31/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4737 - loss: 1.4987 - val_accuracy: 0.4626 - val_loss: 1.5217
# Epoch 32/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4757 - loss: 1.4914 - val_accuracy: 0.4641 - val_loss: 1.5183
# Epoch 33/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4787 - loss: 1.4844 - val_accuracy: 0.4654 - val_loss: 1.5145
# Epoch 34/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4821 - loss: 1.4765 - val_accuracy: 0.4646 - val_loss: 1.5145
# Epoch 35/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4839 - loss: 1.4696 - val_accuracy: 0.4644 - val_loss: 1.5145
# Epoch 36/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4849 - loss: 1.4679 - val_accuracy: 0.4692 - val_loss: 1.4956
# Epoch 37/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4880 - loss: 1.4576 - val_accuracy: 0.4711 - val_loss: 1.4900
# Epoch 38/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4918 - loss: 1.4499 - val_accuracy: 0.4698 - val_loss: 1.4878
# Epoch 39/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4933 - loss: 1.4446 - val_accuracy: 0.4485 - val_loss: 1.5649
# Epoch 40/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4955 - loss: 1.4378 - val_accuracy: 0.4747 - val_loss: 1.4712
# Epoch 41/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4973 - loss: 1.4317 - val_accuracy: 0.4724 - val_loss: 1.4818
# Epoch 42/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5005 - loss: 1.4240 - val_accuracy: 0.4709 - val_loss: 1.4896
# Epoch 43/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5013 - loss: 1.4216 - val_accuracy: 0.4789 - val_loss: 1.4642
# Epoch 44/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5035 - loss: 1.4145 - val_accuracy: 0.4733 - val_loss: 1.4854
# Epoch 45/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5059 - loss: 1.4093 - val_accuracy: 0.4799 - val_loss: 1.4623
# Epoch 46/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5065 - loss: 1.4062 - val_accuracy: 0.4823 - val_loss: 1.4507
# Epoch 47/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5114 - loss: 1.3946 - val_accuracy: 0.4739 - val_loss: 1.4744
# Epoch 48/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5119 - loss: 1.3916 - val_accuracy: 0.4817 - val_loss: 1.4522
# Epoch 49/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5128 - loss: 1.3860 - val_accuracy: 0.4825 - val_loss: 1.4477
# Epoch 50/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5150 - loss: 1.3838 - val_accuracy: 0.4866 - val_loss: 1.4407
# Epoch 51/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5170 - loss: 1.3768 - val_accuracy: 0.4875 - val_loss: 1.4389
# Epoch 52/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5194 - loss: 1.3679 - val_accuracy: 0.4888 - val_loss: 1.4483
# Epoch 53/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5206 - loss: 1.3676 - val_accuracy: 0.4887 - val_loss: 1.4362
# Epoch 54/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5222 - loss: 1.3579 - val_accuracy: 0.4924 - val_loss: 1.4228
# Epoch 55/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5255 - loss: 1.3567 - val_accuracy: 0.4777 - val_loss: 1.4600
# Epoch 56/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5270 - loss: 1.3506 - val_accuracy: 0.4950 - val_loss: 1.4152
# Epoch 57/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5283 - loss: 1.3456 - val_accuracy: 0.4912 - val_loss: 1.4322
# Epoch 58/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5293 - loss: 1.3398 - val_accuracy: 0.5008 - val_loss: 1.3977
# Epoch 59/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5309 - loss: 1.3361 - val_accuracy: 0.4849 - val_loss: 1.4450
# Epoch 60/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5328 - loss: 1.3309 - val_accuracy: 0.4847 - val_loss: 1.4437
# Epoch 61/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5355 - loss: 1.3248 - val_accuracy: 0.4959 - val_loss: 1.4117
# Epoch 62/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5368 - loss: 1.3218 - val_accuracy: 0.4855 - val_loss: 1.4357
# Epoch 63/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5358 - loss: 1.3188 - val_accuracy: 0.4996 - val_loss: 1.3944
# Epoch 64/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5406 - loss: 1.3135 - val_accuracy: 0.5053 - val_loss: 1.3855
# Epoch 65/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5420 - loss: 1.3046 - val_accuracy: 0.5059 - val_loss: 1.3858
# Epoch 66/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5431 - loss: 1.2985 - val_accuracy: 0.4858 - val_loss: 1.4482
# Epoch 67/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5437 - loss: 1.3000 - val_accuracy: 0.5047 - val_loss: 1.3858
# Epoch 68/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5458 - loss: 1.2933 - val_accuracy: 0.5007 - val_loss: 1.4060
# Epoch 69/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5461 - loss: 1.2920 - val_accuracy: 0.4995 - val_loss: 1.4011
# Epoch 70/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5486 - loss: 1.2856 - val_accuracy: 0.5041 - val_loss: 1.3950
# Epoch 71/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5494 - loss: 1.2824 - val_accuracy: 0.4968 - val_loss: 1.4175
# Epoch 72/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5515 - loss: 1.2757 - val_accuracy: 0.5076 - val_loss: 1.3769
# Epoch 73/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5531 - loss: 1.2691 - val_accuracy: 0.4922 - val_loss: 1.4312
# Epoch 74/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5541 - loss: 1.2681 - val_accuracy: 0.4944 - val_loss: 1.4121
# Epoch 75/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5550 - loss: 1.2653 - val_accuracy: 0.5094 - val_loss: 1.3710
# Epoch 76/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5595 - loss: 1.2539 - val_accuracy: 0.5055 - val_loss: 1.3811
# Epoch 77/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5592 - loss: 1.2573 - val_accuracy: 0.5105 - val_loss: 1.3693
# Epoch 78/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5603 - loss: 1.2471 - val_accuracy: 0.4824 - val_loss: 1.4899
# Epoch 79/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5616 - loss: 1.2445 - val_accuracy: 0.5079 - val_loss: 1.3800
# Epoch 80/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5632 - loss: 1.2421 - val_accuracy: 0.5018 - val_loss: 1.3975
# Epoch 81/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5665 - loss: 1.2347 - val_accuracy: 0.5098 - val_loss: 1.3664
# Epoch 82/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5671 - loss: 1.2308 - val_accuracy: 0.5014 - val_loss: 1.4158
# Epoch 83/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5661 - loss: 1.2329 - val_accuracy: 0.5136 - val_loss: 1.3659
# Epoch 84/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5679 - loss: 1.2289 - val_accuracy: 0.5043 - val_loss: 1.3903
# Epoch 85/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5702 - loss: 1.2228 - val_accuracy: 0.5146 - val_loss: 1.3593
# Epoch 86/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5720 - loss: 1.2139 - val_accuracy: 0.5197 - val_loss: 1.3566
# Epoch 87/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5739 - loss: 1.2110 - val_accuracy: 0.4961 - val_loss: 1.4252
# Epoch 88/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5758 - loss: 1.2100 - val_accuracy: 0.4977 - val_loss: 1.4264
# Epoch 89/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5769 - loss: 1.2054 - val_accuracy: 0.5072 - val_loss: 1.3867
# Epoch 90/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5787 - loss: 1.1993 - val_accuracy: 0.5147 - val_loss: 1.3682
# Epoch 91/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5795 - loss: 1.1925 - val_accuracy: 0.5140 - val_loss: 1.3669
# Epoch 92/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5781 - loss: 1.1971 - val_accuracy: 0.5086 - val_loss: 1.3880
# Epoch 93/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5839 - loss: 1.1841 - val_accuracy: 0.5065 - val_loss: 1.4075
# Epoch 94/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5852 - loss: 1.1830 - val_accuracy: 0.5150 - val_loss: 1.3705
# Epoch 95/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5869 - loss: 1.1735 - val_accuracy: 0.5139 - val_loss: 1.3690
# Epoch 96/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5859 - loss: 1.1776 - val_accuracy: 0.5173 - val_loss: 1.3511
# Epoch 97/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5881 - loss: 1.1702 - val_accuracy: 0.5107 - val_loss: 1.3873
# Epoch 98/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5922 - loss: 1.1619 - val_accuracy: 0.4934 - val_loss: 1.4590
# Epoch 99/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5921 - loss: 1.1569 - val_accuracy: 0.5181 - val_loss: 1.3651
# Epoch 100/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5907 - loss: 1.1616 - val_accuracy: 0.5250 - val_loss: 1.3344
# Epoch 101/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5938 - loss: 1.1570 - val_accuracy: 0.5142 - val_loss: 1.3752
# Epoch 102/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5954 - loss: 1.1526 - val_accuracy: 0.5201 - val_loss: 1.3502
# Epoch 103/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5988 - loss: 1.1417 - val_accuracy: 0.4909 - val_loss: 1.4760
# Epoch 104/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5989 - loss: 1.1445 - val_accuracy: 0.5112 - val_loss: 1.3895
# Epoch 105/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6003 - loss: 1.1389 - val_accuracy: 0.5175 - val_loss: 1.3726
# Epoch 106/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6009 - loss: 1.1327 - val_accuracy: 0.5268 - val_loss: 1.3394
# Epoch 107/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5994 - loss: 1.1383 - val_accuracy: 0.5258 - val_loss: 1.3343
# Epoch 108/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6037 - loss: 1.1263 - val_accuracy: 0.5149 - val_loss: 1.3704
# Epoch 109/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6068 - loss: 1.1206 - val_accuracy: 0.5243 - val_loss: 1.3444
# Epoch 110/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6070 - loss: 1.1188 - val_accuracy: 0.5142 - val_loss: 1.3914
# Epoch 111/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6101 - loss: 1.1103 - val_accuracy: 0.5208 - val_loss: 1.3517
# Epoch 112/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6090 - loss: 1.1134 - val_accuracy: 0.5208 - val_loss: 1.3548
# Epoch 113/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6111 - loss: 1.1050 - val_accuracy: 0.5022 - val_loss: 1.4473
# Epoch 114/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6102 - loss: 1.1059 - val_accuracy: 0.5255 - val_loss: 1.3720
# Epoch 115/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6143 - loss: 1.0971 - val_accuracy: 0.5262 - val_loss: 1.3289
# Epoch 116/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6154 - loss: 1.0934 - val_accuracy: 0.5123 - val_loss: 1.4176
# Epoch 117/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6147 - loss: 1.0968 - val_accuracy: 0.5261 - val_loss: 1.3318
# Epoch 118/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6167 - loss: 1.0898 - val_accuracy: 0.5248 - val_loss: 1.3528
# Epoch 119/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6198 - loss: 1.0817 - val_accuracy: 0.5032 - val_loss: 1.4507
# Epoch 120/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6222 - loss: 1.0768 - val_accuracy: 0.5247 - val_loss: 1.3478
# Epoch 121/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6233 - loss: 1.0722 - val_accuracy: 0.5248 - val_loss: 1.3741
# Epoch 122/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6245 - loss: 1.0724 - val_accuracy: 0.5056 - val_loss: 1.4303
# Epoch 123/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6277 - loss: 1.0671 - val_accuracy: 0.5234 - val_loss: 1.3506
# Epoch 124/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6276 - loss: 1.0623 - val_accuracy: 0.5278 - val_loss: 1.3318
# Epoch 125/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6273 - loss: 1.0569 - val_accuracy: 0.5231 - val_loss: 1.3796
# Epoch 126/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6286 - loss: 1.0580 - val_accuracy: 0.5171 - val_loss: 1.4066
# Epoch 127/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6312 - loss: 1.0519 - val_accuracy: 0.5249 - val_loss: 1.3453
# Epoch 128/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6344 - loss: 1.0452 - val_accuracy: 0.5276 - val_loss: 1.3685
# Epoch 129/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6322 - loss: 1.0417 - val_accuracy: 0.5355 - val_loss: 1.3246
# Epoch 130/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6368 - loss: 1.0359 - val_accuracy: 0.5265 - val_loss: 1.3806
# Epoch 131/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6358 - loss: 1.0373 - val_accuracy: 0.5213 - val_loss: 1.4012
# Epoch 132/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6378 - loss: 1.0324 - val_accuracy: 0.5275 - val_loss: 1.3477
# Epoch 133/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6395 - loss: 1.0290 - val_accuracy: 0.5297 - val_loss: 1.3778
# Epoch 134/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6396 - loss: 1.0235 - val_accuracy: 0.5280 - val_loss: 1.3626
# Epoch 135/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6427 - loss: 1.0190 - val_accuracy: 0.5207 - val_loss: 1.4014
# Epoch 136/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6423 - loss: 1.0193 - val_accuracy: 0.5237 - val_loss: 1.4031
# Epoch 137/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6450 - loss: 1.0112 - val_accuracy: 0.5275 - val_loss: 1.3706
# Epoch 138/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6475 - loss: 1.0067 - val_accuracy: 0.5215 - val_loss: 1.3663
# Epoch 139/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6462 - loss: 1.0100 - val_accuracy: 0.5215 - val_loss: 1.3987
# Epoch 140/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6480 - loss: 1.0027 - val_accuracy: 0.5228 - val_loss: 1.3660
# Epoch 141/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6497 - loss: 1.0018 - val_accuracy: 0.5233 - val_loss: 1.4014
# Epoch 142/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6535 - loss: 0.9900 - val_accuracy: 0.5265 - val_loss: 1.3739
# Epoch 143/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6564 - loss: 0.9882 - val_accuracy: 0.5376 - val_loss: 1.3180
# Epoch 144/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6566 - loss: 0.9827 - val_accuracy: 0.5172 - val_loss: 1.3874
# Epoch 145/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6554 - loss: 0.9863 - val_accuracy: 0.5354 - val_loss: 1.3413
# Epoch 146/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6577 - loss: 0.9784 - val_accuracy: 0.5216 - val_loss: 1.3917
# Epoch 147/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6581 - loss: 0.9759 - val_accuracy: 0.5242 - val_loss: 1.4261
# Epoch 148/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6593 - loss: 0.9773 - val_accuracy: 0.5373 - val_loss: 1.3451
# Epoch 149/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6642 - loss: 0.9609 - val_accuracy: 0.5166 - val_loss: 1.4531
# Epoch 150/150
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6608 - loss: 0.9706 - val_accuracy: 0.5245 - val_loss: 1.4116

# %%
# Mostramos la pérdida y el acierto por cada época


#Este grafico (el primero) muestra en el grafico azul la funcion de costo (si decrementa es pq está aprendiendo) de los datos de train
#muestra en el grafico naranjo la funcion de costo (si decrementa es pq está aprendiendo) de los datos de test

#Costo de train decrementa, costo de test aumenta, esto es indicio de overfitting (memorización de test)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Pérdida')
plt.xlabel('Época')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('% Acierto')
plt.xlabel('Época')
plt.show()
