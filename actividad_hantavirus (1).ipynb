# %% [markdown]
# # Experiencia de Aprendizaje 2: Modelos Predictivos en Tiempos de Crisis
# ## Contexto de la Actividad
# Actualmente, nuestra región se encuentra bajo una alerta sanitaria debido a un brote atípico de Hantavirus (Cepa Andes). La alta tasa de contagio ha generado alarma en la población y saturación en los centros de atención.
#
# El Ministerio de Salud nos ha encargado desarrollar un modelo de Machine Learning capaz de realizar un "triaje rápido" para predecir qué pacientes tienen mayor probabilidad de dar positivo al virus, basándose en los datos recopilados en las salas de espera.
#
# **Tu misión:** Entrenar modelos, evaluar sus métricas y determinar cuál es el más apto para ser implementado en los hospitales de la región.

# %% [markdown]
# ## Propósito de la actividad
# 1. Preparar y explorar los datos.
# 2. Entrenar y comparar distintos modelos de clasificación.
# 3. Analizar métricas de desempeño.
# 4. Revisar qué variables están influyendo más en las predicciones.
# 5. Reflexionar críticamente sobre el ejercicio.

# %%
# Si trabajas en Google Colab y el archivo no está en el entorno, sube el CSV manualmente

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.inspection import permutation_importance

SEED = 42

# %% [markdown]
# ## 1. Carga y Exploración de los Datos
# Para este ejercicio, utilizaremos una muestra de datos de pacientes. Analiza las variables disponibles.
#
# Hagan su análisis preliminar.

# %%
df = pd.read_csv('dataset_hantavirus.csv')

# Distribución de la variable objetivo
df["positivo_hantavirus"].value_counts().sort_index().plot(kind="bar")
plt.title("Distribución de casos negativos (0) y positivos (1)")
plt.xlabel("positivo_hantavirus")
plt.ylabel("Frecuencia")
plt.show()

print(df["positivo_hantavirus"].value_counts(normalize=True).rename("proporción"))
# Out:
# positivo_hantavirus
# 1    0.5625
# 0    0.4375
# Name: proporción, dtype: float64

# %%
# Distribución de positivos
sns.countplot(x='positivo_hantavirus', data=df)
plt.title("Distribución de Casos Positivos")
plt.show()

# %% [markdown]
# ## 2. Selección de variables
#
# Para esta primera aproximación:
# - eliminaremos identificadores directos;
# - conservaremos el resto de variables para el modelamiento.

# %% [markdown]
# ## 3. Preprocesamiento
#
# Se aplicará:
# - imputación para nulos,
# - escalamiento en variables numéricas,
# - codificación one-hot para variables categóricas.

# %% [markdown]
# ## 4. Entrenamiento de modelos

# %% [markdown]
# ## 5. Comparación de métricas
#
# - Comparación de métricas por modelo.
# - Matriz de confusión por modelo.

# %% [markdown]
# ¡Excelente trabajo! El modelo ha logrado métricas altísimas, acercándose a la perfección.
# Antes de enviar este modelo al Ministerio de Salud para su implementación hospitalaria, necesitamos interpretar **cómo** está tomando sus decisiones.
#
# Mostrar que caracteristicas son las más importantes

# %% [markdown]
# ## 6. ¿Qué variables están influyendo más?
#
# Aquí comienza la parte crítica de la actividad.
#
# Analiza la importancia de variables sobre los modelos.

# %% [markdown]
# ## 7. Análisis guiado
#
# Responde las siguientes preguntas.

# %% [markdown]
# ### Parte A. Lectura técnica
# 1. ¿Qué modelo obtuvo el mejor puntaje F1 (F1-score) y por qué esta métrica es particularmente relevante en un contexto de salud pública?
# 2. ¿Qué diferencias observas entre la Precisión (Precision) y la Sensibilidad (Recall) en tu mejor modelo?
# 3. En el caso de un virus altamente contagioso, donde el objetivo principal fuera minimizar los falsos negativos (es decir, no enviar a casa a alguien contagiado), ¿seguirías eligiendo el mismo modelo basándote en las métricas? Justifica.
# 4. ¿Qué te muestra la matriz de confusión sobre los tipos de errores que está cometiendo el modelo?
#
# ### Parte B. Interpretación del negocio / contexto
# 5. Observa la importancia de las variables. De las variables que el modelo consideró más influyentes, ¿cuáles te parecen clínicamente razonables para predecir un caso positivo de Hantavirus?
# 6. ¿Qué nivel de relevancia le dio el modelo a las variables netamente clínicas? En contraste, ¿qué variables adoptó el modelo que parecen discutibles, indirectas o injustificables desde un punto de vista sanitario?
# 7. Si llega a la urgencia el paciente "Lorenzo de Médici", quien tiene 40°C de fiebre y fue mordido por un roedor silvestre, pero pertenece a un estrato socioeconómico "Alto" y "No es migrante", ¿qué crees que predecirá tu modelo para él? ¿Por qué sucede esto matemáticamente?
